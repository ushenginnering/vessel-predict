# %% [markdown]
# # **DO not run anything here, till you reach ...(***Start here***)**
#
# **For web app do not run start here** Run from ENds

# %%
import os

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib
import tensorflow.compat.v2.feature_column as fc
import tensorflow as tf

# %%
import ML_model_CargoTYPE_DAYS# import model_t

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# from google.colab import drive
# drive.mount('/content/drive')
import sys    
path_to_module = '/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy'
sys.path.append(path_to_module)
from ML_model_CargoTYPE_DAYS import model_t #convert to .py and it works

# %%
/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/ML_model_CargoTYPE_DAYS.ipynb

# %%
import joblib

# %%
model = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/model.pkl")

# %%
modd = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/days.pkl")

# %%
print(type(modd))
# Out:
# <class 'pandas.core.series.Series'>

# %%
DAYS = modd

# %%
def input_fn(features, batch_size=256):
    #Convert the inputs to a Dataset without labels.
    return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

# features = ['Agent', 'receiver', 'Type', 'Month', 'Tonnage', 'LOA', 'Draft', 'Berth']
	
features = ['Packed', 'Tonnage', 'Receiver',	'Type',	'Berth'] 
predict = {}

print("Please type numeric values as prompted.")
for feature in features:
  valid = True
  while valid: 
    val = input(feature + ": ")
    if not val.isdigit(): valid = False

  predict[feature] = [float(val)]

predictions = model.predict(input_fn=lambda: input_fn(predict))
for pred_dict in predictions:
    class_id = pred_dict['class_ids'][0]
    probability = pred_dict['probabilities'][class_id]

    print('Prediction is "{} Days" ({:.1f}%)'.format(
        DAYS[class_id], 100 * probability))
# Out:
# Please type numeric values as prompted.
# Packed: 1.0
# Tonnage: 3.0
# Receiver: 1.0
# Type: 1.0
# Berth: 2.0
# INFO:tensorflow:Could not find trained model in model_dir: /tmp/tmpxo0vohpk, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "6 Days" (7.4%)

# %% [markdown]
# #**Start Here**

# %%
import os

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib
import tensorflow.compat.v2.feature_column as fc
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/ML_model_CargoTYPE_DAYS.ipynb

# %%
import joblib

# %%
model = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/model.pkl")

# %%
modd = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/days.pkl")

# %%
print(type(modd))
# Out:
# <class 'pandas.core.series.Series'>

# %%
DAYS = modd

# %%
def input_fn(features, batch_size=256):
    #Convert the inputs to a Dataset without labels.
    return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

# features = ['Agent', 'receiver', 'Type', 'Month', 'Tonnage', 'LOA', 'Draft', 'Berth']
	
features = ['Packed', 'Tonnage', 'Receiver',	'Type',	'Berth'] 
predict = {}

print("Please type numeric values as prompted.")
for feature in features:
  valid = True
  while valid: 
    val = input(feature + ": ") + ".0"
    if not val.isdigit(): valid = False

  predict[feature] = [float(val)]

predictions = model.predict(input_fn=lambda: input_fn(predict))
for pred_dict in predictions:
    class_id = pred_dict['class_ids'][0]
    probability = pred_dict['probabilities'][class_id]

    print('Prediction is "{} Days" ({:.1f}%)'.format(
        DAYS[class_id], 100 * probability))
# Out:
# Please type numeric values as prompted.
# Packed: 1.0
# Tonnage: 3.0
# Receiver: 1.0
# Type: 1.0
# Berth: 2.0
# INFO:tensorflow:Could not find trained model in model_dir: /tmp/tmpxo0vohpk, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "6 Days" (7.4%)

# %% [markdown]
# #** Run from here**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls 'drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy'
# Out:
#  app.py				 requirements.txt
# 'calling test.ipynb'		 templates
#  days.pkl			 vessel_model.pkl
#  ML_model_CargoTYPE_DAYS.ipynb	 vessel_model_t.pkl
#  model.pkl			 Web_App.ipynb
#  README.md			'worked_well with import model.py'

# %%
# !less 'drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/app.py'
# Out:
# drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/app.py: No such file or directory

# %%
cd /content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy
# Out:
# /content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy

# %%
# !pip install flask-ngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: flask-ngrok in /usr/local/lib/python3.7/dist-packages (0.0.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (2.23.0)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (1.1.4)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask-ngrok) (2.0.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2.10)

# %%
# # {"nbformat":4,"nbformat_minor":0,"metadata":{"colab":{"name":"app.py","provenance":[],"authorship_tag":"ABX9TyMCTrskvOL8PotWIwe+w7ID"},"kernelspec":{"name":"python3","display_name":"Python 3"},"language_info":{"name":"python"}},"cells":[{"cell_type":"code","execution_count":6,"metadata":{"id":"ONOY5LvWd4s7","executionInfo":{"status":"ok","timestamp":1653739128995,"user_tz":-60,"elapsed":1153,"user":{"displayName":"Ush Engineering","userId":"12457121566292976244"}}},"outputs":[],"source":["\n","def Hello_World():\n","  try:\n","    print(\"Hello World\")\n","\n","  except:\n","    pass"]},{"cell_type":"code","source":["print(f\"Tell them {Hello_World()}, thank you\")"],"metadata":{"colab":{"base_uri":"https://localhost:8080/"},"id":"Z6oT5JzyiJmF","executionInfo":{"status":"ok","timestamp":1653739301085,"user_tz":-60,"elapsed":538,"user":{"displayName":"Ush Engineering","userId":"12457121566292976244"}},"outputId":"005fd065-4cf7-4f8f-ec2a-39fd6aec83a6"},"execution_count":8,"outputs":[{"output_type":"stream","name":"stdout","text":["Hello World\n","Tell them None, thank you\n"]}]}]}

# import numpy as np

# from __future__ import absolute_import, division, print_function, unicode_literals
# import pandas as pd
# import matplotlib.pyplot as plt
# from IPython.display import clear_output
# from six.moves import urllib
# import tensorflow.compat.v2.feature_column as fc
# import tensorflow as tf

# from flask_ngrok import run_with_ngrok
# from flask import Flask, request, render_template
# import pickle
# import joblib

# app = Flask(__name__)

# run_with_ngrok(app)
# model = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/model.pkl")
# # model = pickle.load(open('weight_pred_model.pkl', 'rb'))

# DAYS = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/days.pkl")

# @app.route('/')
# def home():
#     return render_template('index.html')

# @app.route('/getprediction',methods=['POST'])
# def getprediction():    

# #     input = [float(x) for x in request.form.values()]
# #     final_input = [np.array(input)]
# #     prediction = model.predict(final_input)

# #     return render_template('index.html', output='Predicted Weight in KGs :{}'.format(prediction))

# # we use this instead of commented one above
#   def input_fn(features, batch_size=256):
#       #Convert the inputs to a Dataset without labels.
#       return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

# # features = ['Agent', 'receiver', 'Type', 'Month', 'Tonnage', 'LOA', 'Draft', 'Berth']
	
#   features = ['Packed', 'Tonnage', 'Receiver',	'Type',	'Berth'] 
#   predict = {}

#   print("Please type numeric values as prompted.")
#   for feature in features:
#     valid = True
#     while valid:
#       input = [float(x) for x in request.form.values()]
#       val =  [feature + str(input)] 
#       # val = input(feature + ": ") + ".0"
#       #if not val.isdigit(): valid = False

#     predict[feature] = [float(val) for val in request.form.values()]

#   predictions = model.predict(input_fn=lambda: input_fn(predict))
#   for pred_dict in predictions:
#       class_id = pred_dict['class_ids'][0]
#       probability = pred_dict['probabilities'][class_id]

#       print('Prediction is "{} Days" ({:.1f}%)'.format(
#           DAYS[class_id], 100 * probability))

#   return render_template('index.html', output='Prediction is "{} Days" ({:.1f}%)'.format(DAYS[class_id], 100 * probability))
   

# app.run()
# # if __name__ == "__main__":
# #     app.run(debug=True)

# %%
# {"nbformat":4,"nbformat_minor":0,"metadata":{"colab":{"name":"app.py","provenance":[],"authorship_tag":"ABX9TyMCTrskvOL8PotWIwe+w7ID"},"kernelspec":{"name":"python3","display_name":"Python 3"},"language_info":{"name":"python"}},"cells":[{"cell_type":"code","execution_count":6,"metadata":{"id":"ONOY5LvWd4s7","executionInfo":{"status":"ok","timestamp":1653739128995,"user_tz":-60,"elapsed":1153,"user":{"displayName":"Ush Engineering","userId":"12457121566292976244"}}},"outputs":[],"source":["\n","def Hello_World():\n","  try:\n","    print(\"Hello World\")\n","\n","  except:\n","    pass"]},{"cell_type":"code","source":["print(f\"Tell them {Hello_World()}, thank you\")"],"metadata":{"colab":{"base_uri":"https://localhost:8080/"},"id":"Z6oT5JzyiJmF","executionInfo":{"status":"ok","timestamp":1653739301085,"user_tz":-60,"elapsed":538,"user":{"displayName":"Ush Engineering","userId":"12457121566292976244"}},"outputId":"005fd065-4cf7-4f8f-ec2a-39fd6aec83a6"},"execution_count":8,"outputs":[{"output_type":"stream","name":"stdout","text":["Hello World\n","Tell them None, thank you\n"]}]}]}

import numpy as np

from __future__ import absolute_import, division, print_function, unicode_literals
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib
import tensorflow.compat.v2.feature_column as fc
import tensorflow as tf

from flask_ngrok import run_with_ngrok
from flask import Flask, request, render_template
import pickle
import joblib

app = Flask(__name__)

run_with_ngrok(app)
model = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/model.pkl")
# model = pickle.load(open('weight_pred_model.pkl', 'rb'))

DAYS = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/days.pkl")

@app.route('/')
def home():
    return render_template('index.html')

@app.route('/getprediction',methods=['POST'])
def getprediction():    

#     input = [float(x) for x in request.form.values()]
#     final_input = [np.array(input)]
#     prediction = model.predict(final_input)

#     return render_template('index.html', output='Predicted Weight in KGs :{}'.format(prediction))

# we use this instead of commented one above
  def input_fn(features, batch_size=256):
      #Convert the inputs to a Dataset without labels.
      return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

# features = ['Agent', 'receiver', 'Type', 'Month', 'Tonnage', 'LOA', 'Draft', 'Berth']
	
  features = ['Packed', 'Tonnage', 'Receiver',	'Type',	'Berth'] 
  predict = {}

  print("Please type numeric values as prompted.")
  for feature in features:
    valid = True
    # while valid:
    #   val = [float(x) for x in request.form.values()]
    #   # input = [float(x) for x in request.form.values()]
    #   # val =  [feature + str(input)] 
    #   # # val = input(feature + ": ") + ".0"
    #   # #if not val.isdigit(): valid = False
      #THIS CAN BE DONE
      #WHILE VALID:
      #   val = request.form.values() #str(feature + ": " + "request.form.values()")
      #   if not val.isdigit(): valid = False

      #   predict[feature] = [float(val)]

    # for feature in features:
    #   valid = True
    #   while valid: 
    #     val = input(feature + ": ")
    #     if not val.isdigit(): valid = False

    #   predict[feature] = [float(val)]

    predict[feature] = [float(val) for val in request.form.values()]

  predictions = model.predict(input_fn=lambda: input_fn(predict))
  for pred_dict in predictions:
      class_id = pred_dict['class_ids'][0]
      probability = pred_dict['probabilities'][class_id]

      print('Prediction is "{} Days" ({:.1f}%)'.format(
          DAYS[class_id], 100 * probability))

  return render_template('index.html', output='Prediction is "{} Days" ({:.1f}%)'.format(DAYS[class_id], 100 * probability))
   

app.run()
# if __name__ == "__main__":
#     app.run(debug=True)

# %%
import numpy as np

from __future__ import absolute_import, division, print_function, unicode_literals
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib
import tensorflow.compat.v2.feature_column as fc
import tensorflow as tf

from flask_ngrok import run_with_ngrok
from flask import Flask, request, render_template
import pickle
import joblib

app = Flask(__name__)

run_with_ngrok(app)
model = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/model.pkl")
# model = pickle.load(open('weight_pred_model.pkl', 'rb'))

DAYS = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/days.pkl")

@app.route('/')
def home():
    return render_template('index.html')

@app.route('/getprediction',methods=['POST'])
def getprediction():    

  def input_fn(features, batch_size=256):
      #Convert the inputs to a Dataset without labels.
      return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

      # features = ['Agent', 'receiver', 'Type', 'Month', 'Tonnage', 'LOA', 'Draft', 'Berth']
	
  features = ['Packed', 'Tonnage', 'Receiver',	'Type',	'Berth'] 
  predict = {}

  print("Please type numeric values as prompted.")
  for feature in features:
    valid = True
    predict[feature] = [float(val) for val in request.form.values()]

  predictions = model.predict(input_fn=lambda: input_fn(predict))
  for pred_dict in predictions:
      class_id = pred_dict['class_ids'][0]
      probability = pred_dict['probabilities'][class_id]

      print('Prediction is "{} Days" ({:.1f}%)'.format(
          DAYS[class_id], 100 * probability))

  return render_template('index.html', output='Prediction is "{} Days" ({:.1f}%)'.format(DAYS[class_id], 100 * probability))
   

app.run()
# if __name__ == "__main__":
#     app.run(debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://a28f-35-194-239-121.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [31/May/2022 06:55:56] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 06:56:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 06:56:09] "GET /favicon.ico HTTP/1.1" 404 -
# Please type numeric values as prompted.
# INFO:tensorflow:Could not find trained model in model_dir: /tmp/tmpxo0vohpk, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "6 Days" (7.7%)
# Prediction is "6 Days" (9.7%)
# Prediction is "6 Days" (7.7%)
# Prediction is "6 Days" (7.7%)
# Prediction is "6 Days" (9.7%)
# 127.0.0.1 - - [31/May/2022 06:58:25] "POST /getprediction HTTP/1.1" 200 -
# 127.0.0.1 - - [31/May/2022 06:58:26] "GET /getprediction HTTP/1.1" 405 -
# Please type numeric values as prompted.
# INFO:tensorflow:Could not find trained model in model_dir: /tmp/tmpxo0vohpk, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 127.0.0.1 - - [31/May/2022 06:59:32] "POST /getprediction HTTP/1.1" 200 -
# Prediction is "6 Days" (8.2%)
# Prediction is "6 Days" (19.1%)
# Prediction is "6 Days" (13.5%)
# Prediction is "6 Days" (10.8%)
# Prediction is "6 Days" (16.3%)

# %%
# !pip install flask
#print(flask.__version__)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (1.1.4)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask) (1.1.0)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask) (7.1.2)
# Collecting Jinja2<3.0,>=2.10.1
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 4.1 MB/s
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask) (2.0.1)
# Installing collected packages: Jinja2
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 3.1.2
#     Uninstalling Jinja2-3.1.2:
#       Successfully uninstalled Jinja2-3.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbconvert 6.5.0 requires jinja2>=3.0, but you have jinja2 2.11.3 which is incompatible.
# jupyterlab-server 2.14.0 requires jinja2>=3.0.3, but you have jinja2 2.11.3 which is incompatible.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed Jinja2-2.11.3

# %%
for feature in features:
  valid = True
  while valid: 
    val = input(feature + ": ")
    if not val.isdigit(): valid = False

  predict[feature] = [float(val)]

# %%
print(input)
# Out:
# <bound method Kernel.raw_input of <google.colab._kernel.Kernel object at 0x7faf0d1d3050>>

# %%
# !pip install -q colabcode #REMEMBER
# Out:
#      |████████████████████████████████| 45 kB 1.5 MB/s
#      |████████████████████████████████| 8.3 MB 6.6 MB/s
#      |████████████████████████████████| 745 kB 46.8 MB/s
#      |████████████████████████████████| 54 kB 2.7 MB/s
#      |████████████████████████████████| 428 kB 41.1 MB/s
#      |████████████████████████████████| 342 kB 46.2 MB/s
#      |████████████████████████████████| 58 kB 4.8 MB/s
#      |████████████████████████████████| 561 kB 50.0 MB/s
#      |████████████████████████████████| 54 kB 2.2 MB/s
#      |████████████████████████████████| 130 kB 45.6 MB/s
#      |████████████████████████████████| 80 kB 8.4 MB/s
#      |████████████████████████████████| 130 kB 49.0 MB/s
#      |████████████████████████████████| 130 kB 43.3 MB/s
#      |████████████████████████████████| 130 kB 42.8 MB/s
#      |████████████████████████████████| 130 kB 49.4 MB/s
#      |████████████████████████████████| 130 kB 47.5 MB/s
#      |████████████████████████████████| 130 kB 57.8 MB/s
#      |████████████████████████████████| 129 kB 58.7 MB/s
#      |████████████████████████████████| 125 kB 44.1 MB/s
#      |████████████████████████████████| 124 kB 47.4 MB/s
#      |████████████████████████████████| 124 kB 48.3 MB/s
#      |████████████████████████████████| 122 kB 48.9 MB/s
#      |████████████████████████████████| 122 kB 49.8 MB/s
#      |████████████████████████████████| 122 kB 50.3 MB/s
#      |████████████████████████████████| 122 kB 49.6 MB/s
#      |████████████████████████████████| 112 kB 49.0 MB/s
#      |████████████████████████████████| 133 kB 48.6 MB/s
#   Building wheel for pyngrok (setup.py) ... done
#   Building wheel for json5 (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.1.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.

# %%
from colabcode import ColabCode
#from fastapi import FastAPI

# %%
# !ngrok authtoken 29f2INoH5BnrSZnref8fMXY6Bx3_WWoAEk2Bo4uupatrBmZB
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
app.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-6b06a84da215> in <module>()
# ----> 1 app.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
#
# AttributeError: 'Flask' object has no attribute 'setsockopt'
