# %% [markdown]
# #** Run from here**

# %%
import os

# %% [markdown]
# ###mounting google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
#drive.mount("/content/drive", force_remount=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ####Looking through the directory.. **This is a Linux command**

# %%
# !ls 'drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy'
# Out:
#  app.py				 model_gp.pkl
# 'calling test.ipynb'		 model_mtgc.pkl
#  daysbi.pkl			 model_mt.pkl
#  daysgc.pkl			 model.pkl
#  daysgp.pkl			 model_st.pkl
#  daysmtgc.pkl			 model_wt.pkl
#  daysmt.pkl			 model_zc.pkl
#  days.pkl			 README.md
#  daysst.pkl			 requirements.txt
#  dayswt.pkl			 static
#  dayszc.pkl			 templates
#  mini_flask_backe.ipynb		 vessel_model.pkl
#  ML_model_CargoTYPE_DAYS.ipynb	 vessel_model_t.pkl
#  model_bi1.pkl			 Web_App.ipynb
#  model_bi.pkl			'worked_well with import model.py'
#  model_gc.pkl

# %% [markdown]
# ### Don't run **!less**

# %%
# !less 'drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/app.py'
# Out:
# drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/app.py: No such file or directory

# %% [markdown]
# ###changing directory so template can be seen... **google colabs makes it possible to work without this at times**

# %%
cd /content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy
# Out:
# /content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy

# %% [markdown]
# ##Installing dependencies..

# %%
# !pip install flask
#print(flask.__version__)

#if Prediction gives error rerun this and it would clear,..
# I'd put a line to auto downgrade jinja version later..
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (1.1.4)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask) (1.1.0)
# Collecting Jinja2<3.0,>=2.10.1
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 5.1 MB/s
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask) (2.0.1)
# Installing collected packages: Jinja2
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 3.1.2
#     Uninstalling Jinja2-3.1.2:
#       Successfully uninstalled Jinja2-3.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbconvert 6.5.0 requires jinja2>=3.0, but you have jinja2 2.11.3 which is incompatible.
# jupyterlab-server 2.14.0 requires jinja2>=3.0.3, but you have jinja2 2.11.3 which is incompatible.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed Jinja2-2.11.3

# %% [markdown]
# ###**RUN** THIS CELL AFTER INSTALLING FLASK MODULE in above cell..
# #### that is the Change Directory or cd cell below..

# %%
cd /content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy
# Out:
# /content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy

# %%
# !pip install flask-ngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting flask-ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (2.23.0)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask-ngrok) (1.1.4)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (7.1.2)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (2.11.3)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask-ngrok) (2.0.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->flask-ngrok) (1.24.3)
# Installing collected packages: flask-ngrok
# Successfully installed flask-ngrok-0.0.25

# %%
# !pip install -q colabcode #REMEMBER
# Out:
#      |████████████████████████████████| 8.3 MB 5.2 MB/s
#      |████████████████████████████████| 45 kB 3.0 MB/s
#      |████████████████████████████████| 745 kB 44.4 MB/s
#      |████████████████████████████████| 54 kB 2.8 MB/s
#      |████████████████████████████████| 428 kB 25.7 MB/s
#      |████████████████████████████████| 344 kB 46.1 MB/s
#      |████████████████████████████████| 58 kB 5.5 MB/s
#      |████████████████████████████████| 561 kB 41.7 MB/s
#      |████████████████████████████████| 80 kB 8.0 MB/s
#      |████████████████████████████████| 54 kB 2.5 MB/s
#      |████████████████████████████████| 132 kB 24.4 MB/s
#      |████████████████████████████████| 131 kB 50.3 MB/s
#      |████████████████████████████████| 131 kB 47.3 MB/s
#      |████████████████████████████████| 130 kB 43.1 MB/s
#      |████████████████████████████████| 130 kB 51.1 MB/s
#      |████████████████████████████████| 130 kB 48.9 MB/s
#      |████████████████████████████████| 130 kB 50.1 MB/s
#      |████████████████████████████████| 130 kB 49.2 MB/s
#      |████████████████████████████████| 130 kB 45.5 MB/s
#      |████████████████████████████████| 130 kB 19.8 MB/s
#      |████████████████████████████████| 129 kB 24.0 MB/s
#      |████████████████████████████████| 125 kB 36.3 MB/s
#      |████████████████████████████████| 124 kB 34.3 MB/s
#      |████████████████████████████████| 124 kB 29.0 MB/s
#      |████████████████████████████████| 122 kB 38.8 MB/s
#      |████████████████████████████████| 122 kB 28.9 MB/s
#      |████████████████████████████████| 122 kB 40.7 MB/s
#      |████████████████████████████████| 122 kB 31.9 MB/s
#      |████████████████████████████████| 112 kB 37.5 MB/s
#      |████████████████████████████████| 133 kB 35.5 MB/s
#      |████████████████████████████████| 106 kB 34.5 MB/s
#   Building wheel for pyngrok (setup.py) ... done
#   Building wheel for json5 (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# flask 1.1.4 requires Jinja2<3.0,>=2.10.1, but you have jinja2 3.1.2 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.

# %% [markdown]
# ###Importing dependencies

# %%
from colabcode import ColabCode
#from fastapi import FastAPI

# %% [markdown]
# ##AuthToken helps give access to host work on NGRok development environment ...**This token is not to be shared.. !!private!!**

# %%
# !ngrok authtoken 29f2INoH5BnrSZnref8fMXY6Bx3_WWoAEk2Bo4uupatrBmZB
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %% [markdown]
# ##Here, basic flask code for backend is used to connect prediction code from -backend to frontend- for prediction to be carried out..
# **A model saved from prediction model, then its referenced in this prediction backend to enable prediction**

# %% [markdown]
# ##Old index.htm is used here..

# %%
# import numpy as np

# from __future__ import absolute_import, division, print_function, unicode_literals
# import pandas as pd
# import matplotlib.pyplot as plt
# from IPython.display import clear_output
# from six.moves import urllib
# import tensorflow.compat.v2.feature_column as fc
# import tensorflow as tf

# from flask_ngrok import run_with_ngrok
# from flask import Flask, request, render_template
# import pickle
# import joblib

# app = Flask(__name__)

# run_with_ngrok(app)
# model = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/model.pkl")
# # model = pickle.load(open('weight_pred_model.pkl', 'rb'))

# DAYS = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/days.pkl")

# @app.route('/')
# def home():
#     return render_template('index.html')

# @app.route('/getprediction',methods=['POST'])
# def getprediction():    

#   def input_fn(features, batch_size=256):
#       #Convert the inputs to a Dataset without labels.
#       return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

#       # features = ['Agent', 'receiver', 'Type', 'Month', 'Tonnage', 'LOA', 'Draft', 'Berth']
	
#   features = ['Packed', 'Tonnage', 'Receiver',	'Type',	'Berth'] 
#   predict = {}

#   print("Please type numeric values as prompted.")
#   for feature in features:
#     valid = True
#     predict[feature] = [float(val) for val in request.form.values()]

#   predictions = model.predict(input_fn=lambda: input_fn(predict))
#   for pred_dict in predictions:
#       class_id = pred_dict['class_ids'][0]
#       probability = pred_dict['probabilities'][class_id]

#       print('Prediction is "{} Days" ({:.1f}%)'.format(
#           DAYS[class_id], 100 * probability))

#   return render_template('index.html', output='Prediction is "{} Days" ({:.1f}%)'.format(DAYS[class_id], 100 * probability))
   

# app.run()
# # if __name__ == "__main__":
# #     app.run(debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://0800-35-236-152-225.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [04/Jun/2022 12:32:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jun/2022 12:32:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jun/2022 12:32:32] "GET /favicon.ico HTTP/1.1" 404 -

# %%
# OUTPUT 19/07/2021: 3.7.11
# --------------------------------------
import sys
print(sys.version)
# ----------------------[alternative]---
# !python --version  # checks version from command line
# Out:
# 3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0]
# Python 3.7.13

# %%
import numpy as np

from __future__ import absolute_import, division, print_function, unicode_literals
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib
import tensorflow.compat.v2.feature_column as fc
import tensorflow as tf

from flask_ngrok import run_with_ngrok
from flask import Flask, request, render_template
import pickle
import joblib

app = Flask(__name__)

run_with_ngrok(app)
model = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/model_bi.pkl")
# model = pickle.load(open('weight_pred_model.pkl', 'rb'))

DAYS = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/daysbi.pkl")

@app.route('/')
def home():
    return render_template('index.html')

@app.route('/getprediction',methods=['POST'])
def getprediction():    

  def input_fn(features, batch_size=256):
      #Convert the inputs to a Dataset without labels.
      return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

      # features = ['Agent', 'receiver', 'Type', 'Month', 'Tonnage', 'LOA', 'Draft', 'Berth']
	
  features = ['crew_Motivation', 'vessel_Condtion', 'consignee_throughput', 'weather', 'Tonnage', 'Packed'] 
  predict = {}

  print("Please type numeric values as prompted.")
  for feature in features:
    valid = True
    predict[feature] = [float(val) for val in request.form.values()]

  predictions = model.predict(input_fn=lambda: input_fn(predict))
  for pred_dict in predictions:
      class_id = pred_dict['class_ids'][0]
      probability = pred_dict['probabilities'][class_id]

      print('Prediction is "{} Days" ({:.1f}%)'.format(
          DAYS[class_id], 100 * probability))

  return render_template('index.html', output='Prediction is "{} Days" ({:.1f}%)'.format(DAYS[class_id], 100 * probability))
   

app.run()
# if __name__ == "__main__":
#     app.run(debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://1d59-35-224-236-52.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040

# %%
'crew_Motivation', 'vessel_Condtion', 'consignee_throughput', 'weather', 'Tonnage', 'Packed'

# %% [markdown]
# ##New index.htm is used here.. **inside of templates in startup2-1.0.0**

# %% [markdown]
# Do not run the immediate cell below..

# %%
from flask import Flask, render_template
app = Flask(__name__)
@app.route('/')
def home():
    return render_template('home.html')
@app.route('/about/')
def about():
    return render_template('about.html')
if __name__ == '__main__':
    app.run(debug=True)

# %%
from flask import Flask, request, render_template, redirect, url_for

# %%
import numpy as np

from __future__ import absolute_import, division, print_function, unicode_literals
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from six.moves import urllib
import tensorflow.compat.v2.feature_column as fc
import tensorflow as tf

from flask_ngrok import run_with_ngrok
from flask import Flask, request, render_template
import pickle
import joblib

app = Flask(__name__)

run_with_ngrok(app)
model = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/model_bi.pkl")
# model = pickle.load(open('weight_pred_model.pkl', 'rb'))

DAYS = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/daysbi.pkl")

@app.route('/')
def home():
    return render_template('/startup2-1.0.0/iindex.html')
    # return redirect(url_for('/startup2-1.0.0/iindex.html'))

@app.route('/quote')
def quote():
    return render_template('/startup2-1.0.0/quote.html')

@app.route('/contact')
def contact():
    return render_template('/startup2-1.0.0/contact.html')

@app.route('/getprediction',methods=['POST'])
def getprediction():    

  def input_fn(features, batch_size=256):
      #Convert the inputs to a Dataset without labels.
      return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

      # features = ['Agent', 'receiver', 'Type', 'Month', 'Tonnage', 'LOA', 'Draft', 'Berth']
	
  features = ['crew_Motivation', 'vessel_Condition', 'consignee_throughput', 'weather', 'Tonnage', 'Packed'] 
  predict = {}

  print("Please type numeric values as prompted.")
  for feature in features:
    valid = True
    predict[feature] = [float(val) for val in request.form.values()]

  predictions = model.predict(input_fn=lambda: input_fn(predict))
  for pred_dict in predictions:
      class_id = pred_dict['class_ids'][0]
      probability = pred_dict['probabilities'][class_id]

      print('Prediction is "{} Days" ({:.1f}%)'.format(
          DAYS[class_id], 100 * probability))

  return render_template('/startup2-1.0.0/quote.html', output='Prediction is "{} Days" ({:.1f}%)'.format(DAYS[class_id], 100 * probability))
  # return redirect(url_for('/startup2-1.0.0/quote.html', output='Prediction is "{} Days" ({:.1f}%)'.format(DAYS[class_id], 100 * probability))


app.run()
# if __name__ == "__main__":
#     app.run(debug=True)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://cd1c-35-225-22-30.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [11/Jun/2022 14:27:54] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2022 14:27:57] "GET /static/lib/animate/animate.min.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2022 14:27:57] "GET /static/lib/owlcarousel/assets/owl.carousel.min.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2022 14:27:57] "GET /static/css/bootstrap.min.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2022 14:27:57] "GET /static/css/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2022 14:27:57] "GET /static/lib/easing/easing.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2022 14:27:57] "GET /static/lib/wow/wow.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2022 14:27:57] "GET /static/lib/waypoints/waypoints.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2022 14:27:57] "GET /static/lib/counterup/counterup.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2022 14:27:58] "GET /static/lib/owlcarousel/owl.carousel.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2022 14:27:58] "GET /static/js/main.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2022 14:27:58] "GET /static/img/carousel-1.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2022 14:27:58] "GET /static/img/carousel-2.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2022 14:27:58] "GET /static/img/about.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Jun/2022 14:28:07] "GET /static/img/favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Jun/2022 14:28:13] "GET /quote HTTP/1.1" 200 -
# Please type numeric values as prompted.
# INFO:tensorflow:Could not find trained model in model_dir: /tmp/tmpfq_o84ow, running initialization to predict.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Prediction is "3 Days" (7.0%)
# Prediction is "3 Days" (7.0%)
# Prediction is "3 Days" (7.0%)
# Prediction is "3 Days" (7.0%)
# Prediction is "3 Days" (8.3%)
# Prediction is "3 Days" (7.0%)
# 127.0.0.1 - - [11/Jun/2022 14:28:33] "POST /getprediction HTTP/1.1" 200 -

# %%
print(input)
# Out:
# <bound method Kernel.raw_input of <google.colab._kernel.Kernel object at 0x7faf0d1d3050>>

# %% [markdown]
# #End Here

# %%
# # {"nbformat":4,"nbformat_minor":0,"metadata":{"colab":{"name":"app.py","provenance":[],"authorship_tag":"ABX9TyMCTrskvOL8PotWIwe+w7ID"},"kernelspec":{"name":"python3","display_name":"Python 3"},"language_info":{"name":"python"}},"cells":[{"cell_type":"code","execution_count":6,"metadata":{"id":"ONOY5LvWd4s7","executionInfo":{"status":"ok","timestamp":1653739128995,"user_tz":-60,"elapsed":1153,"user":{"displayName":"Ush Engineering","userId":"12457121566292976244"}}},"outputs":[],"source":["\n","def Hello_World():\n","  try:\n","    print(\"Hello World\")\n","\n","  except:\n","    pass"]},{"cell_type":"code","source":["print(f\"Tell them {Hello_World()}, thank you\")"],"metadata":{"colab":{"base_uri":"https://localhost:8080/"},"id":"Z6oT5JzyiJmF","executionInfo":{"status":"ok","timestamp":1653739301085,"user_tz":-60,"elapsed":538,"user":{"displayName":"Ush Engineering","userId":"12457121566292976244"}},"outputId":"005fd065-4cf7-4f8f-ec2a-39fd6aec83a6"},"execution_count":8,"outputs":[{"output_type":"stream","name":"stdout","text":["Hello World\n","Tell them None, thank you\n"]}]}]}

# import numpy as np

# from __future__ import absolute_import, division, print_function, unicode_literals
# import pandas as pd
# import matplotlib.pyplot as plt
# from IPython.display import clear_output
# from six.moves import urllib
# import tensorflow.compat.v2.feature_column as fc
# import tensorflow as tf

# from flask_ngrok import run_with_ngrok
# from flask import Flask, request, render_template
# import pickle
# import joblib

# app = Flask(__name__)

# run_with_ngrok(app)
# model = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/model.pkl")
# # model = pickle.load(open('weight_pred_model.pkl', 'rb'))

# DAYS = joblib.load("/content/drive/MyDrive/Colab Notebooks/Vessel Project/ml-web-app/model-deploy/days.pkl")

# @app.route('/')
# def home():
#     return render_template('index.html')

# @app.route('/getprediction',methods=['POST'])
# def getprediction():    

# #     input = [float(x) for x in request.form.values()]
# #     final_input = [np.array(input)]
# #     prediction = model.predict(final_input)

# #     return render_template('index.html', output='Predicted Weight in KGs :{}'.format(prediction))

# # we use this instead of commented one above
#   def input_fn(features, batch_size=256):
#       #Convert the inputs to a Dataset without labels.
#       return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

# # features = ['Agent', 'receiver', 'Type', 'Month', 'Tonnage', 'LOA', 'Draft', 'Berth']
	
#   features = ['Packed', 'Tonnage', 'Receiver',	'Type',	'Berth'] 
#   predict = {}

#   print("Please type numeric values as prompted.")
#   for feature in features:
#     valid = True
#     while valid:
#       input = [float(x) for x in request.form.values()]
#       val =  [feature + str(input)] 
#       # val = input(feature + ": ") + ".0"
#       #if not val.isdigit(): valid = False

#     predict[feature] = [float(val) for val in request.form.values()]

#   predictions = model.predict(input_fn=lambda: input_fn(predict))
#   for pred_dict in predictions:
#       class_id = pred_dict['class_ids'][0]
#       probability = pred_dict['probabilities'][class_id]

#       print('Prediction is "{} Days" ({:.1f}%)'.format(
#           DAYS[class_id], 100 * probability))

#   return render_template('index.html', output='Prediction is "{} Days" ({:.1f}%)'.format(DAYS[class_id], 100 * probability))
   

# app.run()
# # if __name__ == "__main__":
# #     app.run(debug=True)
