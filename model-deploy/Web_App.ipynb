# %% [markdown]
# ##ML WEB APP
#
#
#
# 1.   How to use flask (JUPYTER NB)
# 2.   Using flask-ngrok (for google colabs), this is used with pyngrok [(https://ngrok.com) for auth token] to enable local url to be public.
# 3.   Using Jupyter-Dash (learn more on this, its a new tech..)
# 4.   Django (find for Azure and google colabs, slightly more advanced than flask.. better for industrial pub..)
# 5.   Others (ex. - Dash(what we are doing), Streamlet, FastApi(with ColabCode), etc)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install jupyter-dash

# %%
impo
